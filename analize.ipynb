# %%
import pandas as pd
from matplotlib import pyplot as plt
import numpy as np

# %%
path = "action_history_20251107_185523.csv"
df = pd.read_csv(path)
columns = ["timestamp", "joint_L_1", "joint_L_2", "joint_R_1", "joint_R_2"]
for col in columns:
    if col == "timestamp":
        continue
    df[col] = df[col] * (180.0 / np.pi)  # rad -> deg
df = df[columns]
df.head()
# Out:
#       timestamp  joint_L_1  joint_L_2  joint_R_1  joint_R_2
# 0  1.762509e+09 -72.208334 -25.959764 -70.784540 -29.921096
# 1  1.762509e+09 -71.195420 -25.686160 -69.976156 -29.871263
# 2  1.762509e+09 -70.323062 -25.550362 -69.121246 -29.848327
# 3  1.762509e+09 -68.511035 -25.444604 -68.056368 -29.845158
# 4  1.762509e+09 -67.221864 -25.377326 -67.834253 -29.977431

# %%
col = "joint_R_2"
plt.figure(figsize=(20, 6))
plt.scatter(df['timestamp'], df[col], label=col, s=2)
plt.xlabel('Timestamp')
plt.ylabel(col + ' Position')
plt.legend()
plt.grid()
plt.show()
